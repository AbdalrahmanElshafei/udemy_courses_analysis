# %% [markdown]
# # Udemy_Courses_Analysis

# %% [markdown]
# #

# %% [markdown]
# ## Importing Libraries & Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
# %matplotlib inline
sns.set()
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Inspecting Datasets

# %%
df = pd.read_csv("udemy_courses_clean.csv")

# %%
df
# Out:
#       Unnamed: 0  course_id  \
# 0              0    1070968
# 1              1    1113822
# 2              2    1006314
# 3              3    1210588
# 4              4    1011058
# ...          ...        ...
# 3678        3678     775618
# 3679        3679    1088178
# 3680        3680     635248
# 3681        3681     905096
# 3682        3682     297602
#
#                                            course_title  \
# 0                    Ultimate Investment Banking Course
# 1     Complete GST Course & Certification - Grow You...
# 2     Financial Modeling for Business Analysts and C...
# 3     Beginner to Pro - Financial Analysis in Excel ...
# 4          How To Maximize Your Profits Trading Options
# ...                                                 ...
# 3678  Learn jQuery from Scratch - Master of JavaScri...
# 3679  How To Design A WordPress Website With No Codi...
# 3680                      Learn and Build using Polymer
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject',
#        'clean_course_title'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3683 entries, 0 to 3682
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           3683 non-null   int64
#  1   course_id            3683 non-null   int64
#  2   course_title         3683 non-null   object
#  3   url                  3683 non-null   object
#  4   is_paid              3683 non-null   object
#  5   price                3683 non-null   object
#  6   num_subscribers      3683 non-null   int64
#  7   num_reviews          3683 non-null   int64
#  8   num_lectures         3683 non-null   int64
#  9   level                3683 non-null   object
#  10  content_duration     3683 non-null   object
#  11  published_timestamp  3683 non-null   object
#  12  subject              3683 non-null   object
#  13  clean_course_title   3663 non-null   object
# dtypes: int64(5), object(9)
# memory usage: 403.0+ KB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0              0
# course_id               0
# course_title            0
# url                     0
# is_paid                 0
# price                   0
# num_subscribers         0
# num_reviews             0
# num_lectures            0
# level                   0
# content_duration        0
# published_timestamp     0
# subject                 0
# clean_course_title     20
# dtype: int64

# %% [markdown]
# ## Subject

# %%
df['subject'].unique()
# Out:
# array(['Business Finance', 'Graphic Design', 'Musical Instruments',
#        'Web Development'], dtype=object)

# %% [markdown]
# ## Which Subject is the most popular?

# %%
df['subject'].value_counts()
# Out:
# subject
# Web Development        1200
# Business Finance       1199
# Musical Instruments     681
# Graphic Design          603
# Name: count, dtype: int64

# %%
df['subject'].value_counts().plot(kind='bar')
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3]),
#  [Text(0, 0, 'Web Development'),
#   Text(1, 0, 'Business Finance'),
#   Text(2, 0, 'Musical Instruments'),
#   Text(3, 0, 'Graphic Design')])

# %%
df['subject'].value_counts().plot(kind='pie',ylabel='')
# Out:
# <Axes: >

# %% [markdown]
# ## Using Seaborn

# %%
sns.countplot(data=df, x=df.subject,palette='tab10')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## num_subscribers

# %% [markdown]
# ### Number of subscribers per subject

# %%
df.groupby('subject')['num_subscribers'].sum()
# Out:
# subject
# Business Finance       1870747
# Graphic Design         1063148
# Musical Instruments     846719
# Web Development        7980572
# Name: num_subscribers, dtype: int64

# %%
df['num_subscribers'].sum()
# Out:
# 11761186

# %%
df['num_subscribers'].max()
# Out:
# 268923

# %%
df['num_subscribers'].min()
# Out:
# 0

# %%
df.groupby('subject')['num_subscribers'].sum().sort_values().plot(
    kind='bar',       # horizontal bar chart بيسهّل القراءة
    color=plt.cm.tab10.colors[:len(df)], 
    title='Total Subscribers per Subject'
)

plt.xlabel('Number of Subscribers')
plt.xticks(rotation=45)
plt.ylabel('Subject')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## The highest number of subscribers "idxman"

# %%
df['num_subscribers'].idxmax()
# Out:
# 2832

# %%
df.iloc[[2832]]
# Out:
#       Unnamed: 0  course_id                          course_title  \
# 2832        2832      41295  Learn HTML5 Programming From Scratch
#
#                                                     url is_paid price  \
# 2832  https://www.udemy.com/learn-html5-programming-...   False  Free
#
#       num_subscribers  num_reviews  num_lectures       level content_duration  \
# 2832           268923         8629            45  All Levels       10.5 hours
#
#        published_timestamp          subject               clean_course_title
# 2832  2013-02-14T07:03:41Z  Web Development  Learn HTML5 Programming Scratch

# %%
df.iloc[2832][['clean_course_title', 'num_subscribers']]
# Out:
# clean_course_title    Learn HTML5 Programming Scratch
# num_subscribers                                268923
# Name: 2832, dtype: object

# %% [markdown]
# # Level

# %% [markdown]
# ## Number of Levels

# %%
df['level'].unique()
# Out:
# array(['All Levels', 'Intermediate Level', 'Beginner Level',
#        'Expert Level', '52'], dtype=object)

# %%
f = (df['level']=='52')
df[f]
# Out:
#       Unnamed: 0  course_id  \
# 2066        2066      96698
#
#                                            course_title    url  \
# 2066  Learn Classical Guitar Technique and play 'Spa...  000!"
#
#                                           is_paid price  num_subscribers  \
# 2066  https://www.udemy.com/learnguitartoworship/  TRUE               30
#
#       num_reviews  num_lectures level content_duration published_timestamp  \
# 2066         1463            29    52   Beginner Level             3 hours
#
#                   subject                                 clean_course_title
# 2066  Musical Instruments  Learn Classical Guitar Technique play Spanish ...

# %%
df.drop(index=2066, inplace=True)

# %% [markdown]
# ## The distribution of courses per levels

# %%
df['level'].value_counts()
# Out:
# level
# All Levels            1932
# Beginner Level        1271
# Intermediate Level     421
# Expert Level            58
# Name: count, dtype: int64

# %%
df['level'].value_counts().plot(kind='bar')
plt.xticks(rotation=45)
plt.show()

# %%
df['level'].value_counts().plot(kind='pie',ylabel='')
plt.show()

# %% [markdown]
# ## Number of subscribers per levels

# %%
df[['num_subscribers','level']]
# Out:
#       num_subscribers               level
# 0                2147          All Levels
# 1                2792          All Levels
# 2                2174  Intermediate Level
# 3                2451          All Levels
# 4                1276  Intermediate Level
# ...               ...                 ...
# 3678             1040          All Levels
# 3679              306      Beginner Level
# 3680              513          All Levels
# 3681              300          All Levels
# 3682              901      Beginner Level
#
# [3682 rows x 2 columns]

# %%
df.groupby('level')['num_subscribers'].sum()
# Out:
# level
# All Levels            6916112
# Beginner Level        4052843
# Expert Level            50196
# Intermediate Level     742005
# Name: num_subscribers, dtype: int64

# %%
df.groupby('level')['num_subscribers'].sum().sort_values().plot(
    kind='bar',
    color=plt.cm.tab10.colors[:len(df)]
)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Number of levels per subject category

# %%
df.groupby('subject')['level'].value_counts()
# Out:
# subject              level
# Business Finance     All Levels            699
#                      Beginner Level        341
#                      Intermediate Level    128
#                      Expert Level           31
# Graphic Design       All Levels            298
#                      Beginner Level        243
#                      Intermediate Level     57
#                      Expert Level            5
# Musical Instruments  Beginner Level        296
#                      All Levels            276
#                      Intermediate Level    101
#                      Expert Level            7
# Web Development      All Levels            659
#                      Beginner Level        391
#                      Intermediate Level    135
#                      Expert Level           15
# Name: count, dtype: int64

# %%
df.groupby('subject')['level'].value_counts().plot(kind='barh',color=plt.cm.tab10.colors[:len(df)])
# Out:
# <Axes: ylabel='subject,level'>

# %%
data = df.groupby(['subject','level']).size()
data = data.unstack(fill_value=0)

# %%
data
# Out:
# level                All Levels  Beginner Level  Expert Level  \
# subject
# Business Finance            699             341            31
# Graphic Design              298             243             5
# Musical Instruments         276             296             7
# Web Development             659             391            15
#
# level                Intermediate Level
# subject
# Business Finance                    128
# Graphic Design                       57
# Musical Instruments                 101
# Web Development                     135

# %%
data.plot(
    kind='barh',
    stacked=True,
    color=plt.cm.Paired.colors[:len(data.columns)]
    
)
plt.xlabel('Number of Courses')
plt.ylabel('Subject')
plt.title('Course Levels by Subject')
plt.tight_layout()
plt.show()

# %%
df.head()
# Out:
#    Unnamed: 0  course_id                                       course_title  \
# 0           0    1070968                 Ultimate Investment Banking Course
# 1           1    1113822  Complete GST Course & Certification - Grow You...
# 2           2    1006314  Financial Modeling for Business Analysts and C...
# 3           3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4           4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url is_paid price  \
# 0  https://www.udemy.com/ultimate-investment-bank...    True   200
# 1      https://www.udemy.com/goods-and-services-tax/    True    75
# 2  https://www.udemy.com/financial-modeling-for-b...    True    45
# 3  https://www.udemy.com/complete-excel-finance-c...    True    95
# 4  https://www.udemy.com/how-to-maximize-your-pro...    True   200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# ...

# %%
sns.countplot(data=df, x='level', hue='subject', palette='tab10')
# Out:
# <Axes: xlabel='level', ylabel='count'>

# %%
df.head()
# Out:
#    Unnamed: 0  course_id                                       course_title  \
# 0           0    1070968                 Ultimate Investment Banking Course
# 1           1    1113822  Complete GST Course & Certification - Grow You...
# 2           2    1006314  Financial Modeling for Business Analysts and C...
# 3           3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4           4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url is_paid price  \
# 0  https://www.udemy.com/ultimate-investment-bank...    True   200
# 1      https://www.udemy.com/goods-and-services-tax/    True    75
# 2  https://www.udemy.com/financial-modeling-for-b...    True    45
# 3  https://www.udemy.com/complete-excel-finance-c...    True    95
# 4  https://www.udemy.com/how-to-maximize-your-pro...    True   200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject',
#        'clean_course_title'],
#       dtype='object')

# %%
def func_draw(x):
    plt.figure(figsize=(10,5))
    sns.barplot(x='level',y=x,data=df,hue='subject',ci=None)
    plt.title(f'plot of {x} per level per subject')
    plt.show()
    #pie chart
    plt.figure(figsize=(10,5))
    df.groupby('level')[x].sum().plot(kind='pie')
    plt.title(f'plot ot {x} per level')
    plt.show()

# %%
func_draw('num_reviews')

# %% [markdown]
# ## Price

# %% [markdown]
# ### The average price of Cources

# %%
df.head()
# Out:
#    Unnamed: 0  course_id                                       course_title  \
# 0           0    1070968                 Ultimate Investment Banking Course
# 1           1    1113822  Complete GST Course & Certification - Grow You...
# 2           2    1006314  Financial Modeling for Business Analysts and C...
# 3           3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4           4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url is_paid price  \
# 0  https://www.udemy.com/ultimate-investment-bank...    True   200
# 1      https://www.udemy.com/goods-and-services-tax/    True    75
# 2  https://www.udemy.com/financial-modeling-for-b...    True    45
# 3  https://www.udemy.com/complete-excel-finance-c...    True    95
# 4  https://www.udemy.com/how-to-maximize-your-pro...    True   200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# ...

# %%
df['price'].unique()
# Out:
# array(['200', '75', '45', '95', '150', '65', '195', '30', '20', '50',
#        '175', '140', '115', '190', '125', '60', '145', '105', '155',
#        '185', '180', '120', '25', '160', '40', 'Free', '100', '90', '35',
#        '80', '70', '55', '165', '130', '85', '170', '110', '135'],
#       dtype=object)

# %%
df['price'] = df['price'].str.replace('Free','0')

# %%
df['price'].unique()
# Out:
# array(['200', '75', '45', '95', '150', '65', '195', '30', '20', '50',
#        '175', '140', '115', '190', '125', '60', '145', '105', '155',
#        '185', '180', '120', '25', '160', '40', '0', '100', '90', '35',
#        '80', '70', '55', '165', '130', '85', '170', '110', '135'],
#       dtype=object)

# %%
df['price'] = df['price'].astype(float)

# %%
df['price'].dtype
# Out:
# dtype('float64')

# %%
df['price'].mean()
# Out:
# 66.01032047800109

# %%
df['price'].max()
# Out:
# 200.0

# %%
df['price'].min()
# Out:
# 0.0

# %% [markdown]
# ### Number of Free courses

# %%
df[df['price'] == 0].shape[0]
# Out:
# 310

# %% [markdown]
# ### Udemy Profit

# %%
#profit = price * subscribers

df['profit'] = df['price'] * df['num_subscribers']

# %%
df['profit']
# Out:
# 0       429400.0
# 1       209400.0
# 2        97830.0
# 3       232845.0
# 4       255200.0
#           ...
# 3678    104000.0
# 3679      7650.0
# 3680     20520.0
# 3681     15000.0
# 3682     40545.0
# Name: profit, Length: 3682, dtype: float64

# %%
df['profit'].sum()
# Out:
# 884982395.0

# %% [markdown]
# ### The most profitable course

# %%
df['profit'].idxmax()
# Out:
# 3235

# %%
df.iloc[3235]
# Out:
# Unnamed: 0                                                   3236
# course_id                                                  164554
# course_title                  AngularJS JumpStart with Dan Wahlin
# url                    https://www.udemy.com/angularjs-jumpstart/
# is_paid                                                      True
# price                                                        75.0
# num_subscribers                                             17802
# num_reviews                                                  2144
# num_lectures                                                  113
# level                                                  All Levels
# content_duration                                         10 hours
# published_timestamp                          2014-03-24T17:31:15Z
# subject                                           Web Development
# clean_course_title                 AngularJS JumpStart Dan Wahlin
# ...

# %% [markdown]
# ## Is paid

# %% [markdown]
# ### Number of paid and free courses

# %%
df['is_paid'].value_counts()
# Out:
# is_paid
# True     2738
# TRUE      634
# False     264
# FALSE      46
# Name: count, dtype: int64

# %%
paid_dic = {'True':True,'TRUE':True,'False':False,'FALSE':False}

# %%
df['is_paid'] = df['is_paid'].map(paid_dic)

# %%
df['is_paid'].value_counts()
# Out:
# is_paid
# True     3372
# False     310
# Name: count, dtype: int64

# %%
df['is_paid'].value_counts().plot(kind = 'pie',autopct='%1.1f%%')
plt.title('Distribution of paid and free courses')
plt.ylabel('')
plt.show()

# %% [markdown]
# ### Number of paid and free courses in each subject category

# %%
df['subject'].unique()
# Out:
# array(['Business Finance', 'Graphic Design', 'Musical Instruments',
#        'Web Development'], dtype=object)

# %%
df.groupby('is_paid')['subject'].value_counts()
# Out:
# is_paid  subject
# False    Web Development         133
#          Business Finance         96
#          Musical Instruments      46
#          Graphic Design           35
# True     Business Finance       1103
#          Web Development        1067
#          Musical Instruments     634
#          Graphic Design          568
# Name: count, dtype: int64

# %%
plt.figure(figsize=(20,10))
df.groupby('is_paid')['subject'].value_counts().plot(kind='barh')
plt.show()

# %%
df.head()
# Out:
#    Unnamed: 0  course_id                                       course_title  \
# 0           0    1070968                 Ultimate Investment Banking Course
# 1           1    1113822  Complete GST Course & Certification - Grow You...
# 2           2    1006314  Financial Modeling for Business Analysts and C...
# 3           3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4           4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True  200.0
# 1      https://www.udemy.com/goods-and-services-tax/     True   75.0
# 2  https://www.udemy.com/financial-modeling-for-b...     True   45.0
# 3  https://www.udemy.com/complete-excel-finance-c...     True   95.0
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True  200.0
#
#    num_subscribers  num_reviews  num_lectures               level  \
# ...

# %% [markdown]
# ## published_timestamp

# %%
df['published_timestamp']
# Out:
# 0       2017-01-18T20:58:58Z
# 1       2017-03-09T16:34:20Z
# 2       2016-12-19T19:26:30Z
# 3       2017-05-30T20:07:24Z
# 4       2016-12-13T14:57:18Z
#                 ...
# 3678    2016-06-14T17:36:46Z
# 3679    2017-03-10T22:24:30Z
# 3680    2015-12-30T16:41:42Z
# 3681    2016-08-11T19:06:15Z
# 3682    2014-09-28T19:51:11Z
# Name: published_timestamp, Length: 3682, dtype: object

# %%
df['published_timestamp'].str.split('T')
# Out:
# 0       [2017-01-18, 20:58:58Z]
# 1       [2017-03-09, 16:34:20Z]
# 2       [2016-12-19, 19:26:30Z]
# 3       [2017-05-30, 20:07:24Z]
# 4       [2016-12-13, 14:57:18Z]
#                  ...
# 3678    [2016-06-14, 17:36:46Z]
# 3679    [2017-03-10, 22:24:30Z]
# 3680    [2015-12-30, 16:41:42Z]
# 3681    [2016-08-11, 19:06:15Z]
# 3682    [2014-09-28, 19:51:11Z]
# Name: published_timestamp, Length: 3682, dtype: object

# %%
df['Published_date'] = df['published_timestamp'].str.split('T').str.get(0)

# %%
df.drop('Published_date',axis=1,inplace=True)

# %%
df
# Out:
#       Unnamed: 0  course_id  \
# 0              0    1070968
# 1              1    1113822
# 2              2    1006314
# 3              3    1210588
# 4              4    1011058
# ...          ...        ...
# 3678        3678     775618
# 3679        3679    1088178
# 3680        3680     635248
# 3681        3681     905096
# 3682        3682     297602
#
#                                            course_title  \
# 0                    Ultimate Investment Banking Course
# 1     Complete GST Course & Certification - Grow You...
# 2     Financial Modeling for Business Analysts and C...
# 3     Beginner to Pro - Financial Analysis in Excel ...
# 4          How To Maximize Your Profits Trading Options
# ...                                                 ...
# 3678  Learn jQuery from Scratch - Master of JavaScri...
# 3679  How To Design A WordPress Website With No Codi...
# 3680                      Learn and Build using Polymer
# ...

# %%
df['published_date'] = df['published_timestamp'].str.split('T').str.get(0)

# %%
df
# Out:
#       Unnamed: 0  course_id  \
# 0              0    1070968
# 1              1    1113822
# 2              2    1006314
# 3              3    1210588
# 4              4    1011058
# ...          ...        ...
# 3678        3678     775618
# 3679        3679    1088178
# 3680        3680     635248
# 3681        3681     905096
# 3682        3682     297602
#
#                                            course_title  \
# 0                    Ultimate Investment Banking Course
# 1     Complete GST Course & Certification - Grow You...
# 2     Financial Modeling for Business Analysts and C...
# 3     Beginner to Pro - Financial Analysis in Excel ...
# 4          How To Maximize Your Profits Trading Options
# ...                                                 ...
# 3678  Learn jQuery from Scratch - Master of JavaScri...
# 3679  How To Design A WordPress Website With No Codi...
# 3680                      Learn and Build using Polymer
# ...

# %%
df['published_date'] = pd.to_datetime(df['published_date'], format='%Y-%m-%d')

# %%
df.dtypes
# Out:
# Unnamed: 0                      int64
# course_id                       int64
# course_title                   object
# url                            object
# is_paid                          bool
# price                         float64
# num_subscribers                 int64
# num_reviews                     int64
# num_lectures                    int64
# level                          object
# content_duration               object
# published_timestamp            object
# subject                        object
# clean_course_title             object
# profit                        float64
# published_date         datetime64[ns]
# dtype: object

# %%
df['year'] = df['published_date'].dt.year
df['month'] = df['published_date'].dt.month
df['day'] = df['published_date'].dt.day

# %%
df.head()
# Out:
#    Unnamed: 0  course_id                                       course_title  \
# 0           0    1070968                 Ultimate Investment Banking Course
# 1           1    1113822  Complete GST Course & Certification - Grow You...
# 2           2    1006314  Financial Modeling for Business Analysts and C...
# 3           3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4           4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True  200.0
# 1      https://www.udemy.com/goods-and-services-tax/     True   75.0
# 2  https://www.udemy.com/financial-modeling-for-b...     True   45.0
# 3  https://www.udemy.com/complete-excel-finance-c...     True   95.0
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True  200.0
#
#    num_subscribers  num_reviews  num_lectures               level  \
# ...

# %%
df['year'].unique()
# Out:
# array([2017, 2016, 2014, 2015, 2013, 2012, 2011])

# %% [markdown]
# ### Number of subscribers per year

# %%
df.groupby('year')['num_subscribers'].sum()
# Out:
# year
# 2011     119028
# 2012     555339
# 2013    1723438
# 2014    1930406
# 2015    3475324
# 2016    2966644
# 2017     990977
# Name: num_subscribers, dtype: int64

# %%
df.groupby('year')['num_subscribers'].sum().plot(kind='barh', color='skyblue')

plt.title('Total Number of Subscribers per Year')   
plt.xlabel('Number of Subscribers')                                
plt.ylabel('Year')                 
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.lineplot(data=df, x='year', y='num_subscribers', hue='subject',ci=None)
plt.title('Total Number of Subscribers per Year per subject',fontsize=20)
plt.legend(fontsize=25)
plt.xlabel('Year', fontsize=16)
plt.ylabel('Number of Subscribers', fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.tight_layout()
plt.show()

# %%
pl
